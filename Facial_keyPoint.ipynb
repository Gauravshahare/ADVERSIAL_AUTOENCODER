# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravshahare/ADVERSIAL_AUTOENCODER/blob/master/Facial_keyPoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install Kaggle API
# !pip install -q kaggle

# %%
import os
os.environ['KAGGLE_USERNAME'] = "jonsnow112"
os.environ['KAGGLE_KEY'] = "123644149fbc1bb15619470f7407e4ef"

# download data from Kaggle
# !kaggle competitions download -c facial-keypoints-detection -p data
# Out:
# training.zip: Skipping, found more recently modified local copy (use --force to force download)
# test.zip: Skipping, found more recently modified local copy (use --force to force download)
# SampleSubmission.csv: Skipping, found more recently modified local copy (use --force to force download)
# IdLookupTable.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Unzip training and test datasets to data directory
# !unzip data/training.zip -d data
# !unzip data/test.zip -d data
# Out:
# Archive:  data/training.zip
# replace data/training.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# Archive:  data/test.zip
# replace data/test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %% [markdown]
# ## Import Pakages

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms, utils

from torch import nn, optim
import torch.nn.functional as F

import warnings
warnings.filterwarnings('ignore')

IMG_SIZE = 96

# %%
data_dir = Path('./data')
train = pd.read_csv(data_dir / 'training.csv')

# %%
train.T
# Out:
#                                                                         0     ...                                               7048
# left_eye_center_x                                                    66.0336  ...                                            66.9383
# left_eye_center_y                                                    39.0023  ...                                            43.4245
# right_eye_center_x                                                    30.227  ...                                            31.0961
# right_eye_center_y                                                   36.4217  ...                                            39.5286
# left_eye_inner_corner_x                                              59.5821  ...                                                NaN
# left_eye_inner_corner_y                                              39.6474  ...                                                NaN
# left_eye_outer_corner_x                                              73.1303  ...                                                NaN
# left_eye_outer_corner_y                                                39.97  ...                                                NaN
# right_eye_inner_corner_x                                             36.3566  ...                                                NaN
# right_eye_inner_corner_y                                             37.3894  ...                                                NaN
# right_eye_outer_corner_x                                             23.4529  ...                                                NaN
# right_eye_outer_corner_y                                             37.3894  ...                                                NaN
# left_eyebrow_inner_end_x                                             56.9533  ...                                                NaN
# left_eyebrow_inner_end_y                                             29.0336  ...                                                NaN
# left_eyebrow_outer_end_x                                             80.2271  ...                                                NaN
# left_eyebrow_outer_end_y                                             32.2281  ...                                                NaN
# right_eyebrow_inner_end_x                                            40.2276  ...                                                NaN
# right_eyebrow_inner_end_y                                            29.0023  ...                                                NaN
# right_eyebrow_outer_end_x                                            16.3564  ...                                                NaN
# right_eyebrow_outer_end_y                                            29.6475  ...                                                NaN
# nose_tip_x                                                           44.4206  ...                                            47.0693
# nose_tip_y                                                           57.0668  ...                                            73.0333
# mouth_left_corner_x                                                  61.1953  ...                                                NaN
# mouth_left_corner_y                                                  79.9702  ...                                                NaN
# mouth_right_corner_x                                                 28.6145  ...                                                NaN
# mouth_right_corner_y                                                  77.389  ...                                                NaN
# mouth_center_top_lip_x                                               43.3126  ...                                                NaN
# mouth_center_top_lip_y                                               72.9355  ...                                                NaN
# mouth_center_bottom_lip_x                                            43.1307  ...                                            45.9005
# mouth_center_bottom_lip_y                                            84.4858  ...                                            82.7731
# Image                      238 236 237 238 240 240 239 241 241 243 240 23...  ...  53 62 67 76 86 91 97 105 105 106 107 108 112 1...
#
# [31 rows x 7049 columns]

# %%
print('size of traning data {}'.format(len(train)))
print('Missing vlaue col ')
print(train.isnull().any().value_counts())
train.isnull().sum().sort_values(ascending=False)
# Out:
# size of traning data 7049
# Missing vlaue col
# True     28
# False     3
# dtype: int64
# left_eyebrow_outer_end_y     4824
# left_eyebrow_outer_end_x     4824
# right_eyebrow_outer_end_y    4813
# right_eyebrow_outer_end_x    4813
# left_eye_outer_corner_x      4782
# left_eye_outer_corner_y      4782
# right_eye_inner_corner_x     4781
# right_eye_inner_corner_y     4781
# right_eye_outer_corner_x     4781
# right_eye_outer_corner_y     4781
# mouth_left_corner_y          4780
# mouth_left_corner_x          4780
# left_eyebrow_inner_end_x     4779
# left_eyebrow_inner_end_y     4779
# right_eyebrow_inner_end_y    4779
# right_eyebrow_inner_end_x    4779
# mouth_right_corner_x         4779
# mouth_right_corner_y         4779
# left_eye_inner_corner_y      4778
# left_eye_inner_corner_x      4778
# mouth_center_top_lip_x       4774
# mouth_center_top_lip_y       4774
# mouth_center_bottom_lip_y      33
# mouth_center_bottom_lip_x      33
# right_eye_center_y             13
# right_eye_center_x             13
# left_eye_center_y              10
# left_eye_center_x              10
# nose_tip_x                      0
# nose_tip_y                      0
# Image                           0
# dtype: int64

# %% [markdown]
# ## Fill the missing values

# %%
train.fillna(method='ffill',inplace=True)

# %%
image_list=[]
for i in train['Image']:
    i=i.split(' ')
    image_list.append(i)
len(image_list)
# Out:
# 7049

# %%
image_list=[]

# %% [markdown]
# ## Plotting the Images

# %%
def show_keypoints(image, keypoints):
    plt.imshow(image, cmap='gray')
    if len(keypoints):
        plt.scatter(keypoints[:, 0], keypoints[:, 1], s=24, marker ='.', c='r')

# %%
def show_images(df, indxs, ncols=5, figsize=(15,10), with_keypoints=True):
  
    plt.figure(figsize=figsize)
    nrows = len(indxs) // ncols + 1
    for i, idx in enumerate(indxs):
        image = np.fromstring(df.loc[idx, 'Image'], sep=' ').astype(np.float32).reshape(-1, IMG_SIZE)
        if with_keypoints:
            keypoints = df.loc[idx].drop('Image').values.astype(np.float32).reshape(-1, 2)
        else:
            keypoints = []
        plt.subplot(nrows, ncols, i + 1)
        plt.title(f'Sample #{idx}')
        plt.axis('off')
        plt.tight_layout()
        show_keypoints(image, keypoints)
    plt.show()

# %%
show_images(train, range(10))

# %%
class FaceKeypointsDataset(Dataset):
    
    
    def __init__(self, dataframe, train=True, transform=None):
        
        
        self.dataframe = dataframe
        self.train = train
        self.transform = transform
        
        
    def __len__(self):
      return len(self.dataframe)
        
    
    def __getitem__(self, idx):
        image = np.fromstring(self.dataframe.iloc[idx, -1], sep=' ')\
                .astype(np.float32).reshape(-1, IMG_SIZE)
    
        if self.train:
            keypoints = self.dataframe.iloc[idx, :-1].values.astype(np.float32)
        else:
            keypoints = None
    
        sample = {'image': image, 'keypoints': keypoints}
        
        if self.transform:
            sample = self.transform(sample)
            
        return sample

# %%
class Normalize(object):
    '''Normalize input images'''
    
    def __call__(self, sample):
        image, keypoints = sample['image'], sample['keypoints']
        
        return {'image': image / 255., # scale to [0, 1]
                'keypoints': keypoints}
        
class ToTensor(object):
    '''Convert ndarrays in sample to Tensors.'''

    def __call__(self, sample):
        image, keypoints = sample['image'], sample['keypoints']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.reshape(1, IMG_SIZE, IMG_SIZE)
        
        image = torch.from_numpy(image)
        
        if keypoints is not None:
            keypoints = torch.from_numpy(keypoints)
            return {'image': image, 'keypoints': keypoints}
        else:
            return {'image': image}

# %%
test_data = pd.read_csv(data_dir / 'test.csv')
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783 entries, 0 to 1782
# Data columns (total 2 columns):
# ImageId    1783 non-null int64
# Image      1783 non-null object
# dtypes: int64(1), object(1)
# memory usage: 27.9+ KB

# %%
from torch.utils.data.sampler import SubsetRandomSampler

# %% [markdown]
# ## Preparing the data and conveting it to pytorch tensors

# %%
def prepare_train_valid_loaders(trainset, valid_size=0.2, 
                                batch_size=128):
    
    # obtain training indices that will be used for validation
    num_train = len(trainset)
    indices = list(range(num_train))
    np.random.shuffle(indices)
    split = int(np.floor(valid_size * num_train))
    train_idx, valid_idx = indices[split:], indices[:split]
    
    # define samplers for obtaining training and validation batches
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)
    
    # prepare data loaders
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                               sampler=train_sampler)
    valid_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                               sampler=valid_sampler)
    
    return train_loader, valid_loader

# %%
# drop any-missing-keypoint records
train_df = train.dropna()
test_df = test_data

# how many samples per batch to load
batch_size = 128
# percentage of training set to use as                                                                                                                
valid_size = 0.2

# Define a transform to normalize the data
tsfm = transforms.Compose([Normalize(), ToTensor()])

# Load the training data and test data

trainset = FaceKeypointsDataset(train_df, transform=tsfm)
testset = FaceKeypointsDataset(test_df, train=False, transform=tsfm)

# prepare data loaders
train_loader, valid_loader = prepare_train_valid_loaders(trainset, valid_size,batch_size)

test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size)

# %%
from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Naive Multilayer Preceptron model

# %% [markdown]
# 96*96 ==> 128 ==> 64==>30
# Regularization : Dropout

# %%
from torch import nn, optim
import torch.nn.functional as F

# %%
class Network(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers, drop_p =0.5):
      super(Network,self).__init__()
      layers=[[hidden_layers[h1],hidden_layers[h2] ] for h1,h2 in zip(range(0,len(hidden_layers)-1 ),range(1,len(hidden_layers) ) )   ]
      layers=[[input_size,hidden_layers[0]]]+layers
      self.h1=nn.ModuleList([nn.Linear(h1[0], h1[1]) for h1 in layers])
      self.batchnorm=nn.ModuleList([nn.BatchNorm1d(h) for h in hidden_layers])
      self.output=nn.Linear(hidden_layers[-1],output_size)
    def forward(self,x):
      x=x.view(x.shape[0],-1)
      for layer1,layer2 in zip(self.h1,self.batchnorm):
        x=F.relu(layer1(x))
        x=layer2(x)
      x=self.output(x)
      return x

# %%
enc=Network(9216,30,[128,64])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
enc = enc.to(device)

# %%
enc
# Out:
# Network(
#   (h1): ModuleList(
#     (0): Linear(in_features=9216, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (batchnorm): ModuleList(
#     (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (output): Linear(in_features=64, out_features=30, bias=True)
# )

# %%
criterion2= nn.MSELoss()
optimizer_dec =  optim.Adam(model.parameters(), lr=10)

# %%
saved_model='enc.pt'

# %%
valid_loss_min = np.Inf
for epoch in range(10):
  l1=0
  v1=0
  for batch in train_loader:
   
    y1=batch['keypoints']
    y=enc(batch['image'].to(device))
    
    l=criterion2(y,batch['keypoints'].to(device) )
    l.backward()
    optimizer.step()
    l1=l1+l.item()
  train_loss = np.sqrt(l1/len(train_loader.sampler.indices))
  
  enc.eval() 
  
  for batch in valid_loader:
    output = enc(batch['image'].to(device))
    loss = criterion2(output, batch['keypoints'].to(device))
    v1+= loss.item()*batch['image'].size(0)
    
  valid_loss = np.sqrt(v1/len(valid_loader.sampler.indices)) 
  
  print("Epoch {} Training Loss : {:.6f} Validation Loss : {:.6f}".format(epoch,train_loss,valid_loss))
  if(valid_loss_min>valid_loss):
    print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'
                  .format(valid_loss_min, valid_loss))
    valid_loss_min=valid_loss
    torch.save(enc.state_dict(), saved_model)
# Out:
# Epoch 0 Training Loss : 4.621024 Validation Loss : 51.708115
# Validation loss decreased (inf --> 51.708115).  Saving model ...
# Epoch 1 Training Loss : 4.622492 Validation Loss : 51.708117
# Epoch 2 Training Loss : 4.621661 Validation Loss : 51.708116
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-180-93f120be56a7> in <module>()
#      17   enc.eval()
#      18
# ---> 19   for batch in valid_loader:
#      20     output = enc(batch['image'].to(device))
#      21     loss = criterion2(output, batch['keypoints'].to(device))
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# <ipython-input-72-a470a6d51c8a> in __getitem__(self, idx)
#      15
#      16     def __getitem__(self, idx):
# ---> 17         image = np.fromstring(self.dataframe.iloc[idx, -1], sep=' ')                .astype(np.float32).reshape(-1, IMG_SIZE)
#      18
#      19         if self.train:
#
# KeyboardInterrupt:

# %%
model = MLP(input_size=IMG_SIZE*IMG_SIZE, output_size=30, 
            hidden_layers=[128, 64], drop_p=0.1)

# %%
enc=network()

# %%
enc
# Out:
# network(
#   (h1): Linear(in_features=9216, out_features=1024, bias=True)
#   (bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (h2): Linear(in_features=1024, out_features=256, bias=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (h3): Linear(in_features=256, out_features=64, bias=True)
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (h4): Linear(in_features=64, out_features=30, bias=True)
#   (bn4): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model  = enc.to(device)

# %% [markdown]
# Loss function ==> Mean Squared Error
#
# Optimizer ==> ADAM

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(enc.parameters(), lr=0.03)

# %%
class network(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers, drop_p =0.5):
      super(MLP, self).__init__()

# %%
layers=[1024,256,64]

# %%
l=[[layers[h1],layers[h2] ] for h1,h2 in zip(range(0,len(layers)-1 ),range(1,len(layers) ) )   ]

# %%
l
# Out:
# [[1024, 256], [256, 64]]

# %%
k=[[h1[0],h1[1]] for h1 in l  ]

# %%
k
# Out:
# [[1024, 256], [256, 64]]

# %%
def Train(train_loader, valid_loader, enc, criterion, optimizer, 
          n_epochs=50, saved_model='model.pt'):
    '''
    Train the model
    
    Args:
        train_loader (DataLoader): DataLoader for train Dataset
        valid_loader (DataLoader): DataLoader for valid Dataset
        model (nn.Module): model to be trained on
        criterion (torch.nn): loss funtion
        optimizer (torch.optim): optimization algorithms
        n_epochs (int): number of epochs to train the model
        saved_model (str): file path for saving model
    
    Return:
        tuple of train_losses, valid_losses
    '''

    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf # set initial "min" to infinity

    train_losses = []
    valid_losses = []

    for epoch in range(n_epochs):
        # monitor training loss
        train_loss = 0.0
        valid_loss = 0.0

        ###################
        # train the model #
        ###################
        enc.train() # prep model for training
        for batch in train_loader:
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = enc(batch['image'].to(device))
            # calculate the loss
            loss = criterion(output, batch['keypoints'].to(device))
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss
            train_loss += loss.item()*batch['image'].size(0)

        ######################    
        # validate the model #
        ######################
        model.eval() # prep model for evaluation
        for batch in valid_loader:
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(batch['image'].to(device))
            # calculate the loss
            loss = criterion(output, batch['keypoints'].to(device))
            # update running validation loss 
            valid_loss += loss.item()*batch['image'].size(0)

        # print training/validation statistics 
        # calculate average Root Mean Square loss over an epoch
        train_loss = np.sqrt(train_loss/len(train_loader.sampler.indices))
        valid_loss = np.sqrt(valid_loss/len(valid_loader.sampler.indices))

        train_losses.append(train_loss)
        valid_losses.append(valid_loss)
        
        
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'
              .format(epoch+1, train_loss, valid_loss))

        # save model if validation loss has decreased
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'
                  .format(valid_loss_min, valid_loss))
            torch.save(model.state_dict(), saved_model)
            valid_loss_min = valid_loss
            
    return train_losses, valid_losses

# %%
train_losses, valid_losses = Train(train_loader, valid_loader, model,
                                   criterion, optimizer, n_epochs=50, 
                                   saved_model='model.pt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-f36311cacbba> in <module>()
#       1 train_losses, valid_losses = Train(train_loader, valid_loader, model,
#       2                                    criterion, optimizer, n_epochs=50,
# ----> 3                                    saved_model='model.pt')
#
# <ipython-input-32-41e26c60c228> in Train(train_loader, valid_loader, enc, criterion, optimizer, n_epochs, saved_model)
#      38             output = enc(batch['image'].to(device))
#      39             # calculate the loss
# ---> 40             loss = criterion(output, batch['keypoints'].to(device))
#      41             # backward pass: compute gradient of the loss with respect to model parameters
#      42             loss.backward()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     441     @weak_script_method
#     442     def forward(self, input, target):
# --> 443         return F.mse_loss(input, target, reduction=self.reduction)
#     444
#     445
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in mse_loss(input, target, size_average, reduce, reduction)
#    2242     See :class:`~torch.nn.MSELoss` for details.
#    2243     """
# -> 2244     if not (target.size() == input.size()):
#    2245         warnings.warn("Using a target size ({}) that is different to the input size ({}). "
#    2246                       "This will likely lead to incorrect results due to broadcasting. "
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %%
# Function to plot RMSE vs epochs
def plot_RMSE(train_losses, valid_losses, y_max=50):
    plt.plot(train_losses, "--", linewidth=3, label="train")
    plt.plot(valid_losses, linewidth=3, label="val")
    plt.legend()
    plt.grid()
    plt.xlabel('Epoch')
    plt.ylabel('RMSE')
    plt.ylim((0, y_max))
    plt.show()

# %%
plot_RMSE(train_losses, valid_losses, y_max=40)

# %%
def predict(data_loader, model):
    '''
    Predict keypoints
    Args:
        data_loader (DataLoader): DataLoader for Dataset
        model (nn.Module): trained model for prediction.
    Return:
        predictions (array-like): keypoints in float (no. of images x keypoints).
    '''
    
    model.eval() # prep model for evaluation

    with torch.no_grad():
        for i, batch in enumerate(data_loader):
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(batch['image'].to(device)).cpu().numpy()
            if i == 0:
                predictions = output
            else:
                predictions = np.vstack((predictions, output))
    
    return predictions

# %%
def view_pred_df(columns, test_df, predictions, image_ids=range(1,6)):
    '''
    Display predicted keypoints
    Args:
        columns (array-like): column names
        test_df (DataFrame): dataframe with ImageId and Image columns
        predictions (array-like): keypoints in float (no. of images x keypoints)
        image_id (array-like): list or range of ImageIds begin at 1
    '''
    pred_df = pd.DataFrame(predictions, columns=columns)
    pred_df = pd.concat([pred_df, test_df], axis=1)
    pred_df = pred_df.set_index('ImageId')
    show_images(pred_df, image_ids)  # ImageId as index begin at 1

# %%
model.load_state_dict(torch.load('model.pt'))
predictions = predict(test_loader, model)
columns = train_df.drop('Image', axis=1).columns
view_pred_df(columns, test_df, predictions)

# %%
def create_submission(predictions, pred_file='data/preds.csv', sub_file='data/submission.csv', columns=None):
    '''
    Create csv file for submission from predictions
    Args:
        predictions (array-like): prediction (no. fo images x 30 keypoints)
        pred_file (string): file path for prediction csv file
        sub_file (string): file path for submission csv file
        columns (dict): provided column names for submission file
    '''
    lookup = pd.read_csv('data/IdLookupTable.csv')
    if columns == None:
        columns = train.columns[:-1]
    preds = pd.DataFrame(predictions, 
                         index=np.arange(1, len(predictions)+1), 
                         columns=columns)
    preds.to_csv(pred_file)
    locations = [preds.loc[image_id, feature_name] 
                 for image_id, feature_name 
                 in lookup[['ImageId', 'FeatureName']].values]
    locations = [location if location < IMG_SIZE else IMG_SIZE for location in locations]
    lookup.Location = pd.Series(locations)
    lookup[['RowId', 'Location']].to_csv(sub_file, index=False)

# %%
create_submission(predictions)

# %%
# !kaggle competitions submit -c facial-keypoints-detection -f data/submission.csv -m "Base MLP"
# Out:
# 100% 629k/629k [00:11<00:00, 57.9kB/s]
# Successfully submitted to Facial Keypoints Detection

# %% [markdown]
# ## Data Augmentation : Vertical , Horizontal , Sideways Flips

# %%
class RandomHorizontalFlip(object):
    '''
    Horizontally flip image randomly with given probability
    Args:
        p (float): probability of the image being flipped.
                   Defalut value = 0.5
    '''
    
    def __init__(self, p=0.5):
        self.p = p

    def __call__(self, sample):
        
        flip_indices = [(0, 2), (1, 3),
                        (4, 8), (5, 9), (6, 10), (7, 11),
                        (12, 16), (13, 17), (14, 18), (15, 19),
                        (22, 24), (23, 25)]
        
        image, keypoints = sample['image'], sample['keypoints']
        
        if np.random.random() < self.p:
            image = image[:, ::-1]
            if keypoints is not None:
                for a, b in flip_indices:
                    keypoints[a], keypoints[b]= keypoints[b], keypoints[a]
                keypoints[::2] = 96. - keypoints[::2]
        
        return {'image': image, 
                'keypoints': keypoints}

# %%
aug_train_df = train.dropna()
aug_transform = transforms.Compose([RandomHorizontalFlip(p=1.0), 
                                    Normalize(),
                                    ToTensor()])
aug_trainset = FaceKeypointsDataset(aug_train_df, transform=aug_transform)

# %%
plt.subplot(1,2,1)
plt.title(f'Original')
plt.axis('off')
plt.tight_layout()
image = trainset[0]['image'].numpy().squeeze()
keypoints = trainset[0]['keypoints'].numpy().reshape(-1,2)
show_keypoints(image, keypoints)
plt.subplot(1,2,2)
plt.title(f'Horizontal Flip')
plt.axis('off')
plt.tight_layout()
image = aug_trainset[0]['image'].numpy().squeeze()
keypoints = aug_trainset[0]['keypoints'].numpy().reshape(-1,2)
show_keypoints(image, keypoints)

# %%
def show_dataset_images(dataset, n_images=10, n_cols=5, figsize=(15,10)):
    '''
    Show Dataset images with keypoints in grids
    Args:
        dataset (Dataset): data
        idxs (iterators): list, Range, Indexes
        ncols (integer): number of columns (images by rows)
        figsize (float, float): width, height in inches
        with_keypoints (boolean): True if data consists of keypoint data
    '''
        
    plt.figure(figsize=figsize)
    n_rows = n_images // n_cols + 1
    for idx in range(n_images):
        image = dataset[idx]['image'].numpy().squeeze()
        keypoints = dataset[idx]['keypoints'].numpy().reshape(-1,2)
        plt.subplot(n_rows, n_cols, idx+1)
        plt.grid(False)
        plt.tight_layout()
        show_keypoints(image, keypoints)

# %%
# how many samples per batch to load
batch_size = 128
# percentage of training set to use as validation
valid_size = 0.2


# Drop missing data
aug_train_df = train.dropna()

# Define a transform to augment the data
aug_tfms = transforms.Compose([RandomHorizontalFlip(p=0.5),
                                    Normalize(),
                                    ToTensor()])

# Load the training data
aug_trainset = FaceKeypointsDataset(aug_train_df, transform=aug_tfms)


# prepare data loaders
aug_train_loader, aug_valid_loader = prepare_train_valid_loaders(aug_trainset, 
                                                                 valid_size,
                                                                 batch_size)

# %%
model = MLP(input_size=IMG_SIZE*IMG_SIZE, output_size=30, hidden_layers=[128, 64], drop_p=0.1)
model = model.to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

# %%
aug_train_losses, aug_valid_losses = Train(aug_train_loader, aug_valid_loader, model, criterion,optimizer, n_epochs=50, saved_model='aug_model.pt')
# Out:
# Epoch: 1 	Training Loss: 22.860821 	Validation Loss: 13.272764
# Validation loss decreased (inf --> 13.272764).  Saving model ...
# Epoch: 2 	Training Loss: 13.705531 	Validation Loss: 11.981106
# Validation loss decreased (13.272764 --> 11.981106).  Saving model ...
# Epoch: 3 	Training Loss: 13.058255 	Validation Loss: 12.005417
# Epoch: 4 	Training Loss: 12.324749 	Validation Loss: 12.773367
# Epoch: 5 	Training Loss: 12.894655 	Validation Loss: 11.049114
# Validation loss decreased (11.981106 --> 11.049114).  Saving model ...
# Epoch: 6 	Training Loss: 11.871960 	Validation Loss: 10.938529
# Validation loss decreased (11.049114 --> 10.938529).  Saving model ...
# Epoch: 7 	Training Loss: 11.668058 	Validation Loss: 12.417581
# Epoch: 8 	Training Loss: 11.975939 	Validation Loss: 12.125110
# Epoch: 9 	Training Loss: 12.170037 	Validation Loss: 11.266348
# Epoch: 10 	Training Loss: 11.634871 	Validation Loss: 11.849771
# Epoch: 11 	Training Loss: 11.202652 	Validation Loss: 10.495876
# Validation loss decreased (10.938529 --> 10.495876).  Saving model ...
# Epoch: 12 	Training Loss: 10.890482 	Validation Loss: 11.651885
# Epoch: 13 	Training Loss: 11.037969 	Validation Loss: 10.344432
# Validation loss decreased (10.495876 --> 10.344432).  Saving model ...
# Epoch: 14 	Training Loss: 10.678658 	Validation Loss: 10.048864
# Validation loss decreased (10.344432 --> 10.048864).  Saving model ...
# Epoch: 15 	Training Loss: 10.481722 	Validation Loss: 10.061224
# Epoch: 16 	Training Loss: 10.548365 	Validation Loss: 10.966768
# Epoch: 17 	Training Loss: 10.151497 	Validation Loss: 9.803907
# Validation loss decreased (10.048864 --> 9.803907).  Saving model ...
# Epoch: 18 	Training Loss: 10.373604 	Validation Loss: 10.088912
# Epoch: 19 	Training Loss: 10.289735 	Validation Loss: 10.514675
# Epoch: 20 	Training Loss: 9.901583 	Validation Loss: 9.278684
# Validation loss decreased (9.803907 --> 9.278684).  Saving model ...
# Epoch: 21 	Training Loss: 9.712626 	Validation Loss: 10.108087
# Epoch: 22 	Training Loss: 9.696572 	Validation Loss: 9.427270
# Epoch: 23 	Training Loss: 9.528912 	Validation Loss: 11.996346
# Epoch: 24 	Training Loss: 10.025861 	Validation Loss: 9.415133
# Epoch: 25 	Training Loss: 9.721563 	Validation Loss: 9.038978
# Validation loss decreased (9.278684 --> 9.038978).  Saving model ...
# Epoch: 26 	Training Loss: 9.180277 	Validation Loss: 9.468995
# Epoch: 27 	Training Loss: 9.297421 	Validation Loss: 9.977517
# Epoch: 28 	Training Loss: 8.879980 	Validation Loss: 8.565762
# Validation loss decreased (9.038978 --> 8.565762).  Saving model ...
# Epoch: 29 	Training Loss: 8.699816 	Validation Loss: 10.800089
# Epoch: 30 	Training Loss: 8.834976 	Validation Loss: 8.081845
# Validation loss decreased (8.565762 --> 8.081845).  Saving model ...
# Epoch: 31 	Training Loss: 8.671898 	Validation Loss: 8.344257
# Epoch: 32 	Training Loss: 8.521569 	Validation Loss: 7.805823
# Validation loss decreased (8.081845 --> 7.805823).  Saving model ...
# Epoch: 33 	Training Loss: 8.552963 	Validation Loss: 8.682150
# Epoch: 34 	Training Loss: 8.813847 	Validation Loss: 7.686908
# Validation loss decreased (7.805823 --> 7.686908).  Saving model ...
# Epoch: 35 	Training Loss: 8.113916 	Validation Loss: 7.942211
# Epoch: 36 	Training Loss: 7.896958 	Validation Loss: 9.241346
# Epoch: 37 	Training Loss: 8.325348 	Validation Loss: 7.276150
# Validation loss decreased (7.686908 --> 7.276150).  Saving model ...
# Epoch: 38 	Training Loss: 7.835035 	Validation Loss: 7.764682
# Epoch: 39 	Training Loss: 7.484966 	Validation Loss: 9.040970
# Epoch: 40 	Training Loss: 8.021102 	Validation Loss: 7.312738
# Epoch: 41 	Training Loss: 7.338192 	Validation Loss: 7.249007
# Validation loss decreased (7.276150 --> 7.249007).  Saving model ...
# Epoch: 42 	Training Loss: 7.334367 	Validation Loss: 6.749251
# Validation loss decreased (7.249007 --> 6.749251).  Saving model ...
# Epoch: 43 	Training Loss: 7.312254 	Validation Loss: 6.603853
# Validation loss decreased (6.749251 --> 6.603853).  Saving model ...
# Epoch: 44 	Training Loss: 7.018351 	Validation Loss: 8.573107
# Epoch: 45 	Training Loss: 7.418723 	Validation Loss: 6.087742
# Validation loss decreased (6.603853 --> 6.087742).  Saving model ...
# Epoch: 46 	Training Loss: 7.941896 	Validation Loss: 10.677881
# Epoch: 47 	Training Loss: 7.822367 	Validation Loss: 8.021181
# Epoch: 48 	Training Loss: 7.194917 	Validation Loss: 9.042108
# Epoch: 49 	Training Loss: 7.420379 	Validation Loss: 6.667465
# Epoch: 50 	Training Loss: 6.931469 	Validation Loss: 6.079928
# Validation loss decreased (6.087742 --> 6.079928).  Saving model ...

# %%
plot_RMSE(aug_train_losses, aug_valid_losses, y_max=40)

# %%
model.load_state_dict(torch.load('aug_model.pt'))
predictions = predict(test_loader, model)
columns = train_df.drop('Image', axis=1).columns
view_pred_df(columns, test_df, predictions)

# %%
create_submission(predictions, 
                  pred_file='data/aug_mlp_preds.csv', 
                  sub_file='data/aug_mlp_submission.csv')

# %%
# !kaggle competitions submit -c facial-keypoints-detection -f data/aug_mlp_submission.csv -m "Augmented MLP"
# Out:
# 100% 628k/628k [00:09<00:00, 65.0kB/s]
# Successfully submitted to Facial Keypoints Detection

# %% [markdown]
# ## Using convolution NN

# %% [markdown]
# 1 * 96 * 96  ==> 16 * 96 * 96 ==> 16 * 48 * 48 ===> 32 * 48 * 48 ===>32 * 24 * 2 4 ===>64 *  12 * 12   ==>64 * 12 * 12 ===>1024 ===> 30

# %%
 class CNN(nn.Module):
    '''
    Convolutional Neural Network model
            
    Args:
        ---------
        output_size (integer): size of the output layer
    '''
    
    def __init__(self, outputs=30):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, padding=1)
        self.conv1_bn = nn.BatchNorm2d(16)
        
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.conv2_bn = nn.BatchNorm2d(32)
        
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3_bn = nn.BatchNorm2d(64)
        
        self.pool = nn.MaxPool2d(2, 2)
        
        self.fc1 = nn.Linear(64*12*12, 1024)
        self.fc2 = nn.Linear(1024, outputs)
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
       
        x = self.pool(F.relu(self.conv1(x)))
        
        x = self.conv1_bn(x)
        
        x = self.pool(F.relu(self.conv2(x)))
        x = self.conv2_bn(x)
        
        x = self.pool(F.relu(self.conv3(x)))
        
        x = self.conv3_bn(x)
        
        x = x.view(-1, 64*12*12)
        
        x = F.relu(self.fc1(self.dropout(x)))
        
        x = self.fc2(self.dropout(x))
        
        return x

# %%
model = CNN(outputs=30)
model = model.to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

# %%
aug_cnn_train_losses, aug_cnn_valid_losses = Train(aug_train_loader, aug_valid_loader, model, criterion, 
                                                   optimizer, n_epochs=50, saved_model='aug_cnn.pt')
# Out:
# Epoch: 1 	Training Loss: 14.988577 	Validation Loss: 11.078042
# Validation loss decreased (inf --> 11.078042).  Saving model ...
# Epoch: 2 	Training Loss: 5.718863 	Validation Loss: 4.909840
# Validation loss decreased (11.078042 --> 4.909840).  Saving model ...
# Epoch: 3 	Training Loss: 5.286941 	Validation Loss: 5.099053
# Epoch: 4 	Training Loss: 4.743743 	Validation Loss: 3.746171
# Validation loss decreased (4.909840 --> 3.746171).  Saving model ...
# Epoch: 5 	Training Loss: 4.465184 	Validation Loss: 3.760493
# Epoch: 6 	Training Loss: 4.397987 	Validation Loss: 3.539737
# Validation loss decreased (3.746171 --> 3.539737).  Saving model ...
# Epoch: 7 	Training Loss: 4.267079 	Validation Loss: 3.439482
# Validation loss decreased (3.539737 --> 3.439482).  Saving model ...
# Epoch: 8 	Training Loss: 4.334687 	Validation Loss: 3.528425
# Epoch: 9 	Training Loss: 4.273211 	Validation Loss: 3.929242
# Epoch: 10 	Training Loss: 4.069159 	Validation Loss: 3.265545
# Validation loss decreased (3.439482 --> 3.265545).  Saving model ...
# Epoch: 11 	Training Loss: 3.994496 	Validation Loss: 3.347892
# Epoch: 12 	Training Loss: 4.027098 	Validation Loss: 5.440446
# Epoch: 13 	Training Loss: 4.307689 	Validation Loss: 3.299102
# Epoch: 14 	Training Loss: 4.007301 	Validation Loss: 3.246804
# Validation loss decreased (3.265545 --> 3.246804).  Saving model ...
# Epoch: 15 	Training Loss: 3.886106 	Validation Loss: 3.521397
# Epoch: 16 	Training Loss: 3.993259 	Validation Loss: 3.350654
# Epoch: 17 	Training Loss: 3.801193 	Validation Loss: 3.495407
# Epoch: 18 	Training Loss: 3.884382 	Validation Loss: 3.437137
# Epoch: 19 	Training Loss: 3.918830 	Validation Loss: 5.375221
# Epoch: 20 	Training Loss: 4.534623 	Validation Loss: 4.566012
# Epoch: 21 	Training Loss: 3.901366 	Validation Loss: 3.479515
# Epoch: 22 	Training Loss: 4.030869 	Validation Loss: 4.184443
# Epoch: 23 	Training Loss: 4.111315 	Validation Loss: 3.086595
# Validation loss decreased (3.246804 --> 3.086595).  Saving model ...
# Epoch: 24 	Training Loss: 3.830485 	Validation Loss: 3.459965
# Epoch: 25 	Training Loss: 4.000079 	Validation Loss: 3.025414
# Validation loss decreased (3.086595 --> 3.025414).  Saving model ...
# Epoch: 26 	Training Loss: 3.635418 	Validation Loss: 3.347888
# Epoch: 27 	Training Loss: 4.015112 	Validation Loss: 3.514139
# Epoch: 28 	Training Loss: 3.824003 	Validation Loss: 3.074021
# Epoch: 29 	Training Loss: 3.821212 	Validation Loss: 3.579009
# Epoch: 30 	Training Loss: 3.605881 	Validation Loss: 3.310599
# Epoch: 31 	Training Loss: 3.549201 	Validation Loss: 3.464366
# Epoch: 32 	Training Loss: 3.640821 	Validation Loss: 3.225195
# Epoch: 33 	Training Loss: 3.506605 	Validation Loss: 2.959368
# Validation loss decreased (3.025414 --> 2.959368).  Saving model ...
# Epoch: 34 	Training Loss: 3.623162 	Validation Loss: 3.706065
# Epoch: 35 	Training Loss: 3.614194 	Validation Loss: 3.127627
# Epoch: 36 	Training Loss: 3.474185 	Validation Loss: 2.944375
# Validation loss decreased (2.959368 --> 2.944375).  Saving model ...
# Epoch: 37 	Training Loss: 3.814331 	Validation Loss: 2.985253
# Epoch: 38 	Training Loss: 3.530882 	Validation Loss: 4.002054
# Epoch: 39 	Training Loss: 3.485798 	Validation Loss: 2.989218
# Epoch: 40 	Training Loss: 3.438208 	Validation Loss: 3.915288
# Epoch: 41 	Training Loss: 3.990509 	Validation Loss: 6.368767
# Epoch: 42 	Training Loss: 4.135213 	Validation Loss: 3.031655
# Epoch: 43 	Training Loss: 3.587270 	Validation Loss: 2.913579
# Validation loss decreased (2.944375 --> 2.913579).  Saving model ...
# Epoch: 44 	Training Loss: 3.821023 	Validation Loss: 2.990266
# Epoch: 45 	Training Loss: 3.536792 	Validation Loss: 2.873912
# Validation loss decreased (2.913579 --> 2.873912).  Saving model ...
# Epoch: 46 	Training Loss: 3.562615 	Validation Loss: 3.340375
# Epoch: 47 	Training Loss: 3.521132 	Validation Loss: 3.073216
# Epoch: 48 	Training Loss: 3.474736 	Validation Loss: 3.508422
# Epoch: 49 	Training Loss: 3.989684 	Validation Loss: 3.367970
# Epoch: 50 	Training Loss: 3.441004 	Validation Loss: 4.322985

# %%
plot_RMSE(aug_cnn_train_losses, aug_cnn_valid_losses, y_max=40)

# %%
model.load_state_dict(torch.load('aug_cnn.pt'))

predictions = predict(test_loader, model)

create_submission(predictions, 
                  pred_file='data/aug_cnn_preds.csv', 
                  sub_file='data/aug_cnn_submission.csv')

view_pred_df(columns, test_df, predictions)

# %%
# !kaggle competitions submit -c facial-keypoints-detection -f data/aug_cnn_submission.csv -m "Augmented CNN"
# Out:
# 100% 629k/629k [00:09<00:00, 64.8kB/s]
# Successfully submitted to Facial Keypoints Detection

# %%
IMG_SIZE
# Out:
# 96
